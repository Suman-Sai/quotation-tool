# %%
#importing the pandas Library 
import pandas as pd
#importing the Numpy Library 
import numpy as np
#importing the Seaborn Library 
import seaborn as sns
#importing the MatPlot Library 
import matplotlib.pyplot as plt
#to avoid the warnings displaying in the execution part import warning library 
import warnings
# This will ignore the FutureWarnings globally for this cell
warnings.filterwarnings('ignore', category=FutureWarning)

# %%
#Read the CSV file to extravt the data....
df_accident=pd.read_csv(r"C:\Users\suman\Downloads\RTA Dataset -  LMS.csv")

#Check the 5 random data using sample()
df_accident.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2440  17:12:00    Thursday              31-50          Male
# 8036   0:28:00    Saturday              31-50          Male
# 5601   8:40:00      Friday            Unknown          Male
# 2532  17:52:00   Wednesday              31-50          Male
# 8052  17:06:00    Thursday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 2440  Junior high school                   Owner             5-10yr
# 8036  Junior high school                Employee          Below 1yr
# 5601  Junior high school                   Owner          Below 1yr
# 2532                 NaN                     NaN                NaN
# 8052  Junior high school                Employee          Below 1yr
#
#         Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2440   Pick up upto 10Q            Owner                  2-5yrs  ...
# 8036       Stationwagen            Owner                 5-10yrs  ...
# 5601    Lorry (41?100Q)            Owner                     NaN  ...
# 2532       Stationwagen            Owner                     NaN  ...
# 8052  Public (12 seats)            Owner                  2-5yrs  ...
#
#      Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 2440   Going straight               na              na                   na
# 8036   Going straight  Driver or rider            Male                18-30
# 5601   Going straight  Driver or rider            Male                31-50
# 2532            Other  Driver or rider          Female                18-30
# 8052   Going straight  Driver or rider            Male                31-50
#
#      Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 2440                na          Employee               Normal
# 8036                 3            Driver               Normal
# 5601                 3     Self-employed               Normal
# 2532                 3               NaN                  NaN
# 8052                 3            Driver               Normal
#
#      Pedestrian_movement                   Cause_of_accident Accident_severity
# 2440    Not a Pedestrian           Changing lane to the left     Slight Injury
# 8036    Not a Pedestrian          Changing lane to the right     Slight Injury
# 5601    Not a Pedestrian              No priority to vehicle     Slight Injury
# 2532    Not a Pedestrian  Getting off the vehicle improperly     Slight Injury
# 8052    Not a Pedestrian           Changing lane to the left     Slight Injury
#
# [5 rows x 32 columns]

# %%
#check the dimensions of the data(observations and variables)
df_accident.shape
# Out:
# (12316, 32)

# %%
#get the data information....
df_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Time                         12316 non-null  object
#  1   Day_of_week                  12316 non-null  object
#  2   Age_band_of_driver           12316 non-null  object
#  3   Sex_of_driver                12316 non-null  object
#  4   Educational_level            11575 non-null  object
#  5   Vehicle_driver_relation      11737 non-null  object
#  6   Driving_experience           11487 non-null  object
#  7   Type_of_vehicle              11366 non-null  object
#  8   Owner_of_vehicle             11834 non-null  object
#  9   Service_year_of_vehicle      8388 non-null   object
#  10  Defect_of_vehicle            7889 non-null   object
#  11  Area_accident_occured        12077 non-null  object
#  12  Lanes_or_Medians             11931 non-null  object
#  13  Road_allignment              12174 non-null  object
#  14  Types_of_Junction            11429 non-null  object
#  15  Road_surface_type            12144 non-null  object
#  16  Road_surface_conditions      12316 non-null  object
#  17  Light_conditions             12316 non-null  object
#  18  Weather_conditions           12316 non-null  object
#  19  Type_of_collision            12161 non-null  object
#  20  Number_of_vehicles_involved  12316 non-null  int64
#  21  Number_of_casualties         12316 non-null  int64
#  22  Vehicle_movement             12008 non-null  object
#  23  Casualty_class               12316 non-null  object
#  24  Sex_of_casualty              12316 non-null  object
#  25  Age_band_of_casualty         12316 non-null  object
#  26  Casualty_severity            12316 non-null  object
#  27  Work_of_casuality            9118 non-null   object
#  28  Fitness_of_casuality         9681 non-null   object
#  29  Pedestrian_movement          12316 non-null  object
#  30  Cause_of_accident            12316 non-null  object
#  31  Accident_severity            12316 non-null  object
# dtypes: int64(2), object(30)
# memory usage: 3.0+ MB

# %%
#Check the Missing Values....
df_accident.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# Casualty_severity                 0
# Work_of_casuality              3198
# Fitness_of_casuality           2635
# Pedestrian_movement               0
# Cause_of_accident                 0
# Accident_severity                 0
# dtype: int64

# %%
#Fill the Missing Values with 0 or any Values....
df_accident.fillna(0)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0      17:02:00      Monday              18-30          Male
# 1      17:02:00      Monday              31-50          Male
# 2      17:02:00      Monday              18-30          Male
# 3       1:06:00      Sunday              18-30          Male
# 4       1:06:00      Sunday              18-30          Male
# ...         ...         ...                ...           ...
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 0       Above high school                Employee              1-2yr
# 1      Junior high school                Employee         Above 10yr
# 2      Junior high school                Employee              1-2yr
# 3      Junior high school                Employee             5-10yr
# 4      Junior high school                Employee              2-5yr
# ...                   ...                     ...                ...
# 12311                   0                Employee              2-5yr
# 12312   Elementary school                Employee             5-10yr
# 12313  Junior high school                Employee             5-10yr
# 12314  Junior high school                Employee         Above 10yr
# 12315  Junior high school                Employee             5-10yr
#
#            Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0               Automobile            Owner              Above 10yr  ...
# 1      Public (> 45 seats)            Owner                 5-10yrs  ...
# 2          Lorry (41?100Q)            Owner                       0  ...
# 3      Public (> 45 seats)     Governmental                       0  ...
# 4                        0            Owner                 5-10yrs  ...
# ...                    ...              ...                     ...  ...
# 12311       Lorry (11?40Q)            Owner                       0  ...
# 12312           Automobile            Owner                       0  ...
# 12313                Bajaj            Owner                  2-5yrs  ...
# 12314      Lorry (41?100Q)            Owner                  2-5yrs  ...
# 12315                Other            Owner                  2-5yrs  ...
#
#       Vehicle_movement   Casualty_class Sex_of_casualty Age_band_of_casualty  \
# 0       Going straight               na              na                   na
# 1       Going straight               na              na                   na
# 2       Going straight  Driver or rider            Male                31-50
# 3       Going straight       Pedestrian          Female                18-30
# 4       Going straight               na              na                   na
# ...                ...              ...             ...                  ...
# 12311   Going straight               na              na                   na
# 12312            Other               na              na                   na
# 12313            Other  Driver or rider            Male                31-50
# 12314            Other               na              na                   na
# 12315         Stopping       Pedestrian          Female                    5
#
#       Casualty_severity Work_of_casuality Fitness_of_casuality  \
# 0                    na                 0                    0
# 1                    na                 0                    0
# 2                     3            Driver                    0
# 3                     3            Driver               Normal
# 4                    na                 0                    0
# ...                 ...               ...                  ...
# 12311                na            Driver               Normal
# 12312                na            Driver               Normal
# 12313                 3            Driver               Normal
# 12314                na            Driver               Normal
# 12315                 3            Driver               Normal
#
#                                      Pedestrian_movement  \
# 0                                       Not a Pedestrian
# 1                                       Not a Pedestrian
# 2                                       Not a Pedestrian
# 3                                       Not a Pedestrian
# 4                                       Not a Pedestrian
# ...                                                  ...
# 12311                                   Not a Pedestrian
# 12312                                   Not a Pedestrian
# 12313                                   Not a Pedestrian
# 12314                                   Not a Pedestrian
# 12315  Crossing from nearside - masked by parked or s...
#
#                           Cause_of_accident Accident_severity
# 0                           Moving Backward     Slight Injury
# 1                                Overtaking     Slight Injury
# 2                 Changing lane to the left    Serious Injury
# 3                Changing lane to the right     Slight Injury
# 4                                Overtaking     Slight Injury
# ...                                     ...               ...
# 12311                         No distancing     Slight Injury
# 12312                         No distancing     Slight Injury
# 12313            Changing lane to the right    Serious Injury
# 12314  Driving under the influence of drugs     Slight Injury
# 12315            Changing lane to the right     Slight Injury
#
# [12316 rows x 32 columns]

# %%
#Converting the date and time using type cast...
df_accident.Time=pd.to_datetime(df_accident.Time, errors='coerce')

# %%
#Recheck the data types....
df_accident.dtypes
# Out:
# Time                           datetime64[ns]
# Day_of_week                            object
# Age_band_of_driver                     object
# Sex_of_driver                          object
# Educational_level                      object
# Vehicle_driver_relation                object
# Driving_experience                     object
# Type_of_vehicle                        object
# Owner_of_vehicle                       object
# Service_year_of_vehicle                object
# Defect_of_vehicle                      object
# Area_accident_occured                  object
# Lanes_or_Medians                       object
# Road_allignment                        object
# Types_of_Junction                      object
# Road_surface_type                      object
# Road_surface_conditions                object
# Light_conditions                       object
# Weather_conditions                     object
# Type_of_collision                      object
# Number_of_vehicles_involved             int64
# Number_of_casualties                    int64
# Vehicle_movement                       object
# Casualty_class                         object
# Sex_of_casualty                        object
# Age_band_of_casualty                   object
# Casualty_severity                      object
# Work_of_casuality                      object
# Fitness_of_casuality                   object
# Pedestrian_movement                    object
# Cause_of_accident                      object
# Accident_severity                      object
# dtype: object

# %%
#extract the various time components()
df_accident=df_accident.assign(hour=df_accident.Time.dt.hour)
df_accident.head()
# Out:
#                  Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 0 2026-05-08 17:02:00      Monday              18-30          Male
# 1 2026-05-08 17:02:00      Monday              31-50          Male
# 2 2026-05-08 17:02:00      Monday              18-30          Male
# 3 2026-05-08 01:06:00      Sunday              18-30          Male
# 4 2026-05-08 01:06:00      Sunday              18-30          Male
#
#     Educational_level Vehicle_driver_relation Driving_experience  \
# 0   Above high school                Employee              1-2yr
# 1  Junior high school                Employee         Above 10yr
# 2  Junior high school                Employee              1-2yr
# 3  Junior high school                Employee             5-10yr
# 4  Junior high school                Employee              2-5yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 0           Automobile            Owner              Above 10yr  ...
# 1  Public (> 45 seats)            Owner                 5-10yrs  ...
# 2      Lorry (41?100Q)            Owner                     NaN  ...
# 3  Public (> 45 seats)     Governmental                     NaN  ...
# 4                  NaN            Owner                 5-10yrs  ...
#
#   Sex_of_casualty Age_band_of_casualty Casualty_severity Work_of_casuality  \
# 0              na                   na                na               NaN
# 1              na                   na                na               NaN
# 2            Male                31-50                 3            Driver
# 3          Female                18-30                 3            Driver
# 4              na                   na                na               NaN
#
#   Fitness_of_casuality Pedestrian_movement           Cause_of_accident  \
# 0                  NaN    Not a Pedestrian             Moving Backward
# 1                  NaN    Not a Pedestrian                  Overtaking
# 2                  NaN    Not a Pedestrian   Changing lane to the left
# 3               Normal    Not a Pedestrian  Changing lane to the right
# 4                  NaN    Not a Pedestrian                  Overtaking
#
#   Accident_severity hour day
# 0     Slight Injury   17   8
# 1     Slight Injury   17   8
# 2    Serious Injury   17   8
# 3     Slight Injury    1   8
# 4     Slight Injury    1   8
#
# [5 rows x 34 columns]

# %%
#Drop the Columns using drop(), axis=1 drops the specific columns
df_accident=df_accident.drop(['day','Time'],axis=1)

# %%
df_accident.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12316 entries, 0 to 12315
# Data columns (total 32 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Day_of_week                  12316 non-null  object
#  1   Age_band_of_driver           12316 non-null  object
#  2   Sex_of_driver                12316 non-null  object
#  3   Educational_level            11575 non-null  object
#  4   Vehicle_driver_relation      11737 non-null  object
#  5   Driving_experience           11487 non-null  object
#  6   Type_of_vehicle              11366 non-null  object
#  7   Owner_of_vehicle             11834 non-null  object
#  8   Service_year_of_vehicle      8388 non-null   object
#  9   Defect_of_vehicle            7889 non-null   object
#  10  Area_accident_occured        12077 non-null  object
#  11  Lanes_or_Medians             11931 non-null  object
#  12  Road_allignment              12174 non-null  object
#  13  Types_of_Junction            11429 non-null  object
#  14  Road_surface_type            12144 non-null  object
#  15  Road_surface_conditions      12316 non-null  object
#  16  Light_conditions             12316 non-null  object
#  17  Weather_conditions           12316 non-null  object
#  18  Type_of_collision            12161 non-null  object
#  19  Number_of_vehicles_involved  12316 non-null  int64
#  20  Number_of_casualties         12316 non-null  int64
#  21  Vehicle_movement             12008 non-null  object
#  22  Casualty_class               12316 non-null  object
#  23  Sex_of_casualty              12316 non-null  object
#  24  Age_band_of_casualty         12316 non-null  object
#  25  Casualty_severity            12316 non-null  object
#  26  Work_of_casuality            9118 non-null   object
#  27  Fitness_of_casuality         9681 non-null   object
#  28  Pedestrian_movement          12316 non-null  object
#  29  Cause_of_accident            12316 non-null  object
#  30  Accident_severity            12316 non-null  object
#  31  hour                         12316 non-null  int32
# dtypes: int32(1), int64(2), object(29)
# memory usage: 3.0+ MB

# %%
# Generate the correlation matrix by explicitly ignoring strings
corr = df_accident.corr(numeric_only=True)

# Display the correlation matrix
corr
# Out:
#                              Number_of_vehicles_involved  \
# Number_of_vehicles_involved                     1.000000
# Number_of_casualties                            0.213427
# hour                                            0.023095
#
#                              Number_of_casualties      hour
# Number_of_vehicles_involved              0.213427  0.023095
# Number_of_casualties                     1.000000  0.051761
# hour                                     0.051761  1.000000

# %%
#Generating the heat map...
# Set the figure size
plt.figure(figsize=(5,5))

# Create the heatmap
# annot=True adds the numbers into the squares
# cmap='coolwarm' makes positive correlations red and negative ones blue
sns.heatmap(corr, annot=True, cmap='RdYlGn', fmt=".2f", linewidths=0.5, annot_kws= {"size":10})

# Add a title
plt.title('Correlation Heatmap of Accident Data')
#set the text size using fontsize
plt.xticks(fontsize = 8)
plt.yticks(fontsize = 8)
plt.show()

# %%
#Clear, evidence-based findings such as "Accidents peak between 5 PM and 7 PM" or "Rainy weather conditions significantly increase accident severity levels."

#Peak Accidents between timeframes plot....
df_accident['hour'].value_counts().sort_index().plot(title='Peak Accidents Time Frame',kind='line')
#Severity accident levels for weather severity plot...
#normalize= 'index' , will converts those counts into percentages (proportions) based on the row total.
#without normalize m it shows the raw data like daylight=50,000 accidents and all.....
pd.crosstab(df_accident['Light_conditions'], df_accident['Accident_severity'], normalize='index')
# Out:
# Accident_severity        Fatal injury  Serious Injury  Slight Injury
# Light_conditions
# Darkness - lights lit        0.020085        0.141509       0.838405
# Darkness - lights unlit      0.000000        0.175000       0.825000
# Darkness - no lighting       0.026042        0.255208       0.718750
# Daylight                     0.009889        0.138895       0.851216

# %%
#Professional charts showing accidents by time of day, severity by weather conditions, and vehicle type involvement patterns.

# --- Set Global Aesthetics ---
sns.set_theme(style="whitegrid")
plt.rcParams['figure.dpi'] = 100

# Create a figure with three subplots
fig, axes = plt.subplots(1, 3, figsize=(20, 6))

# 1. ACCIDENTS BY TIME OF DAY (Line Chart)
# Grouping by hour and counting incidents
hourly_data = df_accident['hour'].value_counts().sort_index().reset_index()
hourly_data.columns = ['Hour', 'Count']

sns.lineplot(data=hourly_data, x='Hour', y='Count', marker='o', color='#2c3e50', ax=axes[0])
axes[0].fill_between(hourly_data['Hour'], hourly_data['Count'], color='#34495e', alpha=0.1)
axes[0].set_title('Accident Distribution by Hour', fontweight='bold')
axes[0].set_xticks(range(0, 24, 2)) # Simple way to show every 2nd hour

# 2. SEVERITY BY LIGHTING (Stacked Bar Chart)
# Using your cross-tab logic to show percentages
severity_pct = pd.crosstab(df_accident['Light_conditions'], 
                           df_accident['Accident_severity'], 
                           normalize='index') * 100

severity_pct.plot(kind='bar', stacked=True, ax=axes[1], color=['#e74c3c', '#f39c12', '#bdc3c7'])
axes[1].set_title('Severity % by Light Conditions', fontweight='bold')
axes[1].set_ylabel('Percentage (%)')
axes[1].legend(title='Severity', loc='center', bbox_to_anchor=(0.5,0.8), ncol=3)
axes[1].tick_params(axis='x', rotation=45)

# 3. VEHICLE TYPE INVOLVEMENT (Horizontal Bar Chart)
top_vehicles = df_accident['Type_of_vehicle'].value_counts().head(10)

sns.barplot(x=top_vehicles.values, y=top_vehicles.index, palette='viridis', ax=axes[2])
axes[2].set_title('Top 10 Involved Vehicle Types', fontweight='bold')
axes[2].set_xlabel('Total Incidents')

# Adjust layout to prevent label overlap
plt.tight_layout()
plt.show()
