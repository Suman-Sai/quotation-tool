# %%
print('Welcome Sumanth...!');
# Out:
# Welcome Sumanth...!

# %%
name = 'Sumanth'
Age=25
salary=50000.50
status = True
print("Employee Name:"+name+"\n"+"Employee Salary:"+str(salary)+'\n'+"Employee Status:"+str(status))
# Out:
# Employee Name:Sumanth
# Employee Salary:50000.5
# Employee StatusTrue

# %%
name=input("Enter name:")
print(name)
# Out:
# Enter name: Sachin
# Sachin

# %%
a=20
b=5
print("Addition of sum :",str(a+b))
a+b
# Out:
# Addition of sum : 25
# 25

# %%
a=int(input("Enter the First Number :"))
b=int(input("Enter the Second Number :"))
print("Addition of a&b:",str(a+b)
      +"\n"+
      "subtraction of a&b:",str(a-b)
      +"\n"+
      "Multiplaction of A&B: "+str(a*b));
# Out:
# Enter the First Number : 12
# Enter the Second Number : 4
# Addition of a&b: 16
# subtraction of a&b: 8
# Multiplaction of A&B: 48

# %%
a=int(input("Enter the First Number :"))
b=int(input("Enter the Second Number :"))
c= input("Choose the Arithmetic Operation: ")
if(c=='Add'):
    print("Sum of the is",str(a+b))
elif(c=='Sub'):
    print("Sum of the is",str(a-b))
else:
    print("Invalid operation selected....!")
# Out:
# Enter the First Number : 1
# Enter the Second Number : 2
# Choose the Arithmetic Operation:  123
# Invalid operation selected....!

# %%
age = int(input("Enter your age: "))
nationality = input("Enter your Nationality: ")
if age>=18 and nationality=="Indian":
    print("Eligible to vote")
elif age>=18 and nationality!="Indian":
    print("You are eligible to open bank account...!")
elif age<=18 and nationality=="Indian":
    print("You are eligible for government schemes...!")
else:
    print("You are not an Indian ...!")
# Out:
# Enter your age:  25
# Enter your Nationality:  Indian
# Eligible to vote

# %%
range(1,10)
# Out:
# range(1, 10)

# %%
for i in range(1,10,2):
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9

# %%
i=int(input("Enter the number"))
j=int(input("Enter the number to stop"))
while(i<=j):
    print("Hello World...!")
    i=i+1
# Out:
# Enter the number 1
# Enter the number to stop 5
# Hello World...!
# Hello World...!
# Hello World...!
# Hello World...!
# Hello World...!

# %%
number= input("Enter the number")
for i in number:
    for j in range(6):
        print('*',end=" ")
    print("")
# Out:
# Enter the number

# %%
for i in range(1,6):
    for j in range(1,i+1):
        print("*",end=" ")
    print("")
for i in range(6,1,-1):
    for j in range(1,i-1):
        print("*",end=" ")
    print("")
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
num1=input('Enter the first Number:')
num2=input('Enter the Second Number:')
print("The Product for the 2 numbers is: ",int(num1)*int(num2))
# Out:
# Enter the first Number: 4
# Enter the Second Number: 3
# The Product for the 2 numbers is:  12
