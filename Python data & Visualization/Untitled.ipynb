# %%
a = 100;
def fun():
    a = 'Function';
    print(a);

print(a);
fun();
# Out:
# 100
# Function

# %%
apple = 10

apple = 9

print(apple)
# Out:
# 9

# %%
a = 5
a
# Out:
# 5

# %%
bin(a)
# Out:
# '0b101'

# %%
oct(a)
# Out:
# '0o5'

# %%
str(a)
# Out:
# '5'
