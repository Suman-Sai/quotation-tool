# %%
name1="John"
name2="Sachin"
name3="Viren"

print(name)
# Out:
# Viren

# %%
#List      names=["John","Sachin","Viren"]  age=[30,32,24]   details=[101,"John","Manager",50000.50,True] - Mutable
#Tuple     names=("John","Sachin","Viren")  age=(30,32,24)   details=101,"John","Manager",50000.50,True    - Imutable 
#Dictionary details={empid:101,empname:"John",desig:"Manager",sal:50000.50,status:True}
#Set

books=["Java","Python","SAS","R","SPSS"]
books
# Out:
# ['Java', 'Python', 'SAS', 'R', 'SPSS']

# %%
len(books)
type(books)
# Out:
# list

# %%
books[4]
books[2:4]
# Out:
# ['SAS', 'R']

# %%
books.append("C")

# %%
books
# Out:
# ['Java', 'Python', 'SAS', 'R', 'SPSS', 'C']

# %%
books.insert(2,"C++")

# %%
books
# Out:
# ['Java', 'Python', 'C++', 'SAS', 'R', 'SPSS', 'C']

# %%
books.remove("R")

# %%
books
# Out:
# ['Java', 'Python', 'C++', 'SAS', 'SPSS', 'C']

# %%
books.pop(3)
# Out:
# 'SAS'

# %%
books
# Out:
# ['Java', 'Python', 'C++', 'SPSS', 'C']

# %%
books.sort()
books.sort(reverse=True)

# %%
books
# Out:
# ['SPSS', 'Python', 'Java', 'C++', 'C']

# %%
b=["Java","Python","SAS","R","SPSS"]
newbooks=sorted(b,reverse=True)
newbooks
# Out:
# ['SPSS', 'SAS', 'R', 'Python', 'Java']

# %%
age=[30,32,24]
age.sort()
age
# Out:
# [24, 30, 32]

# %%
details=[101,"John","Manager",50000.50,True]
#details.sort()

print(101 not in details)                    #Membership operators - in and not in
# Out:
# False

# %%
for i in details:
    print(i)
# Out:
# 101
# John
# Manager
# 50000.5
# True

# %%
dairy=["Milk", "Curd","Yoghurt"]
other=["Cheese", "Butter"]

dairy.extend(other)

# %%
dairy
# Out:
# ['Milk', 'Curd', 'Yoghurt', 'Cheese', 'Butter']

# %%
dairy=["Milk", "Curd","Yoghurt"]
other=["Cheese", "Butter"]
dairyproducts=dairy+other
dairyproducts
# Out:
# ['Milk', 'Curd', 'Yoghurt', 'Cheese', 'Butter']

# %%
dairy=["Milk", "Curd","Yoghurt"]
#dairy[::-1]
dairy.reverse()
dairy
# Out:
# ['Yoghurt', 'Curd', 'Milk']

# %%
dairy=["Milk", "Curd","Yoghurt","Milk"]
dairy.count("Milk")
dairy.index("Milk")
len(dairy)
# Out:
# 4

# %%
myt=(40,10,30,5.6,100,90,1000,800)
myt
# Out:
# (40, 10, 30, 5.6, 100, 90, 1000, 800)

# %%
myt[0]
myt[-1]
myt[2:5]
# Out:
# (30, 5.6, 100)

# %%
#myt.append(500)
#myt.sort()
yourt=sorted(myt)
yourt
# Out:
# [5.6, 10, 30, 40, 90, 100, 800, 1000]

# %%
#del myt[1]

min(myt)
max(myt)
len(myt)
# Out:
# 8

# %%
myt=(40,10,30,5.6,100,[90,1000],800)
len(myt)
# Out:
# 7

# %%
myt[5].append(3000)

# %%
myt
# Out:
# (40, 10, 30, 5.6, 100, [90, 1000, 3000], 800)

# %%
del myt[5][1]

# %%
myt
# Out:
# (40, 10, 30, 5.6, 100, [90, 3000], 800)

# %%
myt=(40,10,30,5.6,100,90,1000,800)

for j in myt:
    print(j)
# Out:
# 40
# 10
# 30
# 5.6
# 100
# 90
# 1000
# 800

# %%
details={"empid":101,"empname":"John","desig":"Manager","sal":50000.50,"status":True}
details
# Out:
# {'empid': 101,
#  'empname': 'John',
#  'desig': 'Manager',
#  'sal': 50000.5,
#  'status': True}

# %%
type(details)
#type(myt)
# Out:
# dict

# %%
details["sal"]
# Out:
# 50000.5

# %%
details["bonus"]=1000
details
# Out:
# {'empid': 101,
#  'empname': 'John',
#  'desig': 'Manager',
#  'sal': 50000.5,
#  'status': True,
#  'bonus': 1000}

# %%
len(details)
# Out:
# 6

# %%
del details["bonus"]

# %%
details
# Out:
# {'empid': 101,
#  'empname': 'John',
#  'desig': 'Manager',
#  'sal': 50000.5,
#  'status': True}

# %%
details["sal"]=90000.50

# %%
details
# Out:
# {'empid': 101,
#  'empname': 'John',
#  'desig': 'Manager',
#  'sal': 90000.5,
#  'status': True}

# %%
details.keys()
# Out:
# dict_keys(['empid', 'empname', 'desig', 'sal', 'status'])

# %%
details.values()
# Out:
# dict_values([101, 'John', 'Manager', 90000.5, True])

# %%
details.items()
# Out:
# dict_items([('empid', 101), ('empname', 'John'), ('desig', 'Manager'), ('sal', 90000.5), ('status', True)])

# %%
details.get("sal","Not avaialable")
#details["sal"]
# Out:
# 90000.5

# %%
for k,v in details.items():
    print(k,"-->",v)
# Out:
# empid --> 101
# empname --> John
# desig --> Manager
# sal --> 90000.5
# status --> True

# %%
# list(), tuple(), dict(), set()

students={"S1":{"name":"Aarav","marks":90},"S2":{"name":"Sachin","marks":70}}
students.keys()
students.values()
students["S2"]["marks"]
# Out:
# 70

# %%
newdetails=details.copy()
newdetails
# Out:
# {'empid': 101,
#  'empname': 'John',
#  'desig': 'Manager',
#  'sal': 90000.5,
#  'status': True}

# %%
#sets
fruits={"Cherry","Banana","Apple","Orange","Banana"}
print(fruits)
# Out:
# {'Cherry', 'Apple', 'Orange', 'Banana'}

# %%
a={1,2,3}
b={3,4,5}
a.union(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
a|b
# Out:
# {1, 2, 3, 4, 5}

# %%
a.intersection(b)
# Out:
# {3}

# %%
a&b
# Out:
# {3}

# %%
a.difference(b)
# Out:
# {1, 2}

# %%
b.difference(a)
# Out:
# {4, 5}

# %%
a-b
# Out:
# {1, 2}

# %%
b-a
# Out:
# {4, 5}

# %%
a.symmetric_difference(b)
# Out:
# {1, 2, 4, 5}

# %%
a^b
# Out:
# {1, 2, 4, 5}

# %%
squares=[]

for x in range(1,11):
    squares.append(x*x)
print(squares)
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
[i*i for i in range(1,11) if i>5]
# Out:
# [36, 49, 64, 81, 100]

# %%
[x for x in range(10) if x%2==1]
# Out:
# [1, 3, 5, 7, 9]
