# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Superstore.csv", encoding = "latin-1")
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import chardet

with open("Superstore.csv", "rb") as f:
    result = chardet.detect(f.read(10000))

encoding = result["encoding"]
print(encoding)
# Out:
# ISO-8859-1

# %%
pd.set_option("display.max_columns", None)

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
sns.histplot(df["Sales"], bins = 20)
# Out:
# <Axes: xlabel='Sales', ylabel='Count'>

# %%
df[df["Sales"] == df["Sales"].max()]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 2697    2698  CA-2014-145317  3/18/2014  3/23/2014  Standard Class
#
#      Customer ID Customer Name      Segment        Country          City  \
# 2697    SM-20320   Sean Miller  Home Office  United States  Jacksonville
#
#         State  Postal Code Region       Product ID    Category Sub-Category  \
# 2697  Florida        32216  South  TEC-MA-10002412  Technology     Machines
#
#                                            Product Name     Sales  Quantity  \
# 2697  Cisco TelePresence System EX90 Videoconferenci...  22638.48         6
#
#       Discount     Profit
# 2697       0.5 -1811.0784

# %%
sean_miller = df[df["Customer ID"] == "SM-20320"]

# %%
sean_miller.describe()
# Out:
#             Row ID   Postal Code         Sales   Quantity   Discount  \
# count    15.000000     15.000000     15.000000  15.000000  15.000000
# mean   5169.666667  32139.400000   1669.536667   3.333333   0.246667
# std    3227.989393  18133.346704   5807.087126   1.447494   0.184649
# min    2267.000000  18103.000000      3.488000   2.000000   0.000000
# 25%    2698.500000  18103.000000     14.448000   2.000000   0.200000
# 50%    2702.000000  32216.000000     30.768000   3.000000   0.200000
# 75%    9188.500000  32216.000000    324.401000   4.000000   0.200000
# max    9192.000000  90049.000000  22638.480000   6.000000   0.700000
#
#             Profit
# count    15.000000
# mean   -132.049287
# std     467.115828
# min   -1811.078400
# 25%      -8.561800
# 50%       3.802400
# 75%       7.779100
# max      31.587000

# %%
sean_miller["Discount"].value_counts()
# Out:
# Discount
# 0.2    10
# 0.0     2
# 0.5     2
# 0.7     1
# Name: count, dtype: int64

# %%
df["Discount"].value_counts().sort_index().plot(kind = "bar")
# Out:
# <Axes: xlabel='Discount'>

# %%
sns.scatterplot(x = "Discount", y = "Profit", data = df)
# Out:
# <Axes: xlabel='Discount', ylabel='Profit'>

# %%
sns.heatmap(df[["Discount", "Profit"]].corr(), annot = True, vmin = -1)
# Out:
# <Axes: >

# %% [markdown]
# # Inference
# 1) The store is giving huge amounts of discount.
# 2) Everytime the store gives more than 40% discount, the store always makes a loss.
# 3) Just because store made sales of 22k, it still made a loss of -1811. Because of 50% which is more 40%.
#
# # Prescription
# 1) Store should have better discounting strategies.

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City       State  \
# 0      Claire Gute   Consumer  United States        Henderson    Kentucky
# 1      Claire Gute   Consumer  United States        Henderson    Kentucky
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  California
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale     Florida
#
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
for col_name in ['Segment', 'State', 'Region', 'Category', 'Sub-Category', 'Product Name']:
    plt.figure(figsize = (7,5))
    plt.title(col_name)
    df.groupby(col_name)["Profit"].sum().sort_values(ascending = False).plot(kind = "bar")
    plt.show()

# %%
df["Category"].value_counts().sort_values(ascending = False)
# Out:
# Category
# Office Supplies    6026
# Furniture          2121
# Technology         1847
# Name: count, dtype: int64

# %%
df.groupby("Category")["Profit"].sum().sort_values(ascending = False)
# Out:
# Category
# Technology         145454.9481
# Office Supplies    122490.8008
# Furniture           18451.2728
# Name: Profit, dtype: float64

# %%
Furniture = df[df["Category"] == "Furniture"]

# %%
Furniture["Sub-Category"].value_counts()
# Out:
# Sub-Category
# Furnishings    957
# Chairs         617
# Tables         319
# Bookcases      228
# Name: count, dtype: int64

# %%
Furniture.groupby("Sub-Category")["Profit"].sum().sort_values(ascending = False)
# Out:
# Sub-Category
# Chairs         26590.1663
# Furnishings    13059.1436
# Bookcases      -3472.5560
# Tables        -17725.4811
# Name: Profit, dtype: float64

# %% [markdown]
# # Inference
# 1) Furniture is the 2nd best selling category yet its the least profit making category.
# 2) Tables and Bookcases are making loss for the store.
# 3) Techology makes more profit even though its sales are less.
#
# # Prescription
# 1) Store can stop selling tables or lower stocks of tables since it makes loss.
# 2) Store can work on Bookcases and find a way to make profit.
# 3) Tech stocks could be increased as they make large profits.

# %%
df["Region"].value_counts()
# Out:
# Region
# West       3203
# East       2848
# Central    2323
# South      1620
# Name: count, dtype: int64

# %%
df.groupby("Region")["Profit"].sum().sort_values(ascending = False)
# Out:
# Region
# West       108418.4489
# East        91522.7800
# South       46749.4303
# Central     39706.3625
# Name: Profit, dtype: float64

# %%
df[df["Region"] == "Central"]["State"].value_counts().plot(kind = "bar")
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# # inference
# 1) Central region is the least profit making region.
# 2) Texas and Illinois are making loss which is in the central region.
#
# # Prescription
# 1) Have better discounting strategies at Texas and Illinois.
