# %%
import os
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
for dirpath, dirnames, filenames in os.walk(r"C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET"):
    print(f"There are {len(dirnames)} directories and {len(filenames)} images in '{dirpath}'.")
# Out:
# There are 3 directories and 0 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET'.
# There are 3 directories and 0 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\test'.
# There are 0 directories and 437 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\test\buildings'.
# There are 0 directories and 474 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\test\forest'.
# There are 0 directories and 510 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\test\sea'.
# There are 3 directories and 0 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\train'.
# There are 0 directories and 1752 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\train\buildings'.
# There are 0 directories and 1816 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\train\forest'.
# There are 0 directories and 1819 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\train\sea'.
# There are 3 directories and 0 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\val'.
# There are 0 directories and 439 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\val\buildings'.
# There are 0 directories and 455 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\val\forest'.
# There are 0 directories and 455 images in 'C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET\val\sea'.

# %%
# Directory path
#train &  test are file folders ...
base_dir = r"C:\Users\suman\Downloads\project on CNN\DATASET - LMS (3) (1)\DATASET"
train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')

# Training Directory Path
#buildins , Forest, Sea are folders of images ...

train_buildings_dir = os.path.join(train_dir, 'buildings')
train_forest_dir = os.path.join(train_dir, 'forest')
train_sea_dir = os.path.join(train_dir, 'sea')

# %%
# creating user defined functions to extract the images ...
ncols = 4
nrows = 1
num_images = 4

def view_random_image(target_dir):
    fig = plt.gcf()
    fig.set_size_inches(ncols * 4, nrows * 4)
    
    random_image = random.sample(os.listdir(target_dir), num_images)
    
    for i, img_path in enumerate(random_image):
        ax = plt.subplot(nrows, ncols, i + 1)
        ax.axis('off')
        
        img = mpimg.imread(os.path.join(target_dir, img_path))
        plt.imshow(img)
        plt.title(os.path.basename(target_dir))
        
    plt.show()

# %%
view_random_image(train_buildings_dir)

# %%
view_random_image(train_forest_dir)

# %%
view_random_image(train_sea_dir)
