# %% [markdown]
# ### T-Test
# * it is of 2-types:
#     * 1-Sample Test
#     * 2-Sample test

# %% [markdown]
# ### 1-Sample Test

# %%
import numpy as np
from scipy import stats
import pandas as pd

data = pd.read_csv('data.csv')
